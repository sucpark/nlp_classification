# %%
import pandas as pd
import nltk
import json
import pickle
from pathlib import Path
from utils import sent2words

# %%
data_dir = Path('dataset')
train_data_name = 'sw_train.txt'
valid_data_name = 'sw_val.txt'
test_data_name = 'sw_test.txt'

# %%
train_data = pd.read_csv(data_dir / train_data_name, header=None, sep='|', names=['speaker','utterance','tag'])
valid_data = pd.read_csv(data_dir / valid_data_name, header=None, sep='|', names=['speaker','utterance','tag'])
test_data = pd.read_csv(data_dir / test_data_name, header=None, sep='|', names=['speaker','utterance','tag'])

# %%
train_data
# Out:
#        speaker                                          utterance  \
# 0            A                                              Okay.
# 1            A  So, What kind of experience do you, do you hav...
# 2            B     I guess, I think, uh, I wonder if that worked.
# 3            A                             Does it say something?
# 4            B                           I think it usually does.
# ...        ...                                                ...
# 192381       B                                             it is.
# 192382       B                                      It really is.
# 192383       B                                              Yeah,
# 192384       B                                      it really is.
# 192385       B                                        And I felt,
#
#                     tag
# 0       fo_o_fw_"_by_bc
# 1                    qw
# 2                  qy^d
# 3                    qy
# 4                    sd
# ...                 ...
# 192381               sd
# 192382               sd
# 192383               ny
# 192384               sd
# 192385               sd
#
# [192386 rows x 3 columns]

# %%
valid_data
# Out:
#      speaker                                          utterance  \
# 0          B                                     Um, all right.
# 1          A                                          I've, uh,
# 2          A  as far as I'm concerned, I find that the young...
# 3          A  and I think that comes about from their being ...
# 4          B                                            Uh-huh.
# ...      ...                                                ...
# 3267       B  and I know they've, there's a lot of refinerie...
# 3268       B  and that, that's some pretty potent stuff they...
# 3269       B             I, but I don't know how, uh, you know,
# 3270       B  there's a difference in what you can smell and...
# 3271       A  Be interesting to see when, as Mexico develops...
#
#                   tag
# 0     fo_o_fw_"_by_bc
# 1                   %
# 2                  sv
# 3                  sv
# 4                  aa
# ...               ...
# 3267               sd
# 3268               sv
# 3269               sd
# 3270               sv
# 3271               sv
#
# [3272 rows x 3 columns]

# %%
test_data
# Out:
#      speaker                                          utterance  \
# 0          A                                          Okay, uh,
# 1          A  could you tell me what you think contributes m...
# 2          B                            Well, it's hard to say.
# 3          B  I mean, while it's certainly the case that thi...
# 4          B                                 What do you think?
# ...      ...                                                ...
# 4073       B                                   I appreciate it.
# 4074       A                                              Okay.
# 4075       B                                   Catch you later.
# 4076       A                                           Bye-bye.
# 4077       B                                           Bye-bye.
#
#                   tag
# 0     fo_o_fw_"_by_bc
# 1                  qw
# 2                  ^h
# 3                  sv
# 4                  qo
# ...               ...
# 4073               fc
# 4074               fc
# 4075               fc
# 4076               fc
# 4077               fc
#
# [4078 rows x 3 columns]

# %%
utterances = pd.concat([train_data['utterance'], valid_data['utterance'], test_data['utterance']], axis=0, ignore_index=True)
utterances
# Out:
# 0                                                     Okay.
# 1         So, What kind of experience do you, do you hav...
# 2            I guess, I think, uh, I wonder if that worked.
# 3                                    Does it say something?
# 4                                  I think it usually does.
#                                 ...
# 199731                                     I appreciate it.
# 199732                                                Okay.
# 199733                                     Catch you later.
# 199734                                             Bye-bye.
# 199735                                             Bye-bye.
# Name: utterance, Length: 199736, dtype: object

# %%
word2idx = {}
word2idx['<PAD>'] = 0  
for i, sent in enumerate(utterances):
    temp_words = sent2words(sent)
    for w in temp_words:
        if w not in word2idx:
            word2idx[w] = len(word2idx)

# idx2word = {i:w for w,i in word2idx.items()}

# %%
idx2word
# Out:
# {0: '<PAD>',
#  1: 'okay',
#  2: '.',
#  3: 'so',
#  4: ',',
#  5: 'what',
#  6: 'kind',
#  7: 'of',
#  8: 'experience',
#  9: 'do',
#  10: 'you',
#  11: 'have',
#  12: 'then',
#  13: 'with',
#  14: 'child',
#  15: 'care',
#  16: '?',
#  17: 'i',
#  18: 'guess',
#  19: 'think',
#  20: 'uh',
#  21: 'wonder',
#  22: 'if',
#  23: 'that',
#  24: 'worked',
#  25: 'does',
#  26: 'it',
#  27: 'say',
#  28: 'something',
#  29: 'usually',
#  30: 'might',
#  31: 'try',
#  32: "n't",
#  33: 'know',
#  34: 'hold',
#  35: 'down',
#  36: 'a',
#  37: 'little',
#  38: 'longer',
#  39: 'and',
#  40: 'see',
#  41: 'well',
#  42: 'make',
#  43: 'recording',
#  44: 'or',
#  45: 'remember',
#  46: 'seemed',
#  47: 'like',
#  48: 'did',
#  49: 'but',
#  50: 'not',
#  51: 'we',
#  52: 'can',
#  53: 'start',
#  54: 'no',
#  55: 'any',
#  56: 'kids',
#  57: 'my',
#  58: 'sister',
#  59: 'has',
#  60: 'she',
#  61: 'just',
#  62: 'had',
#  63: 'baby',
#  64: 'he',
#  65: "'s",
#  66: 'about',
#  67: 'five',
#  68: 'months',
#  69: 'old',
#  70: 'was',
#  71: 'worrying',
#  72: 'going',
#  73: 'back',
#  74: 'to',
#  75: 'work',
#  76: 'him',
#  77: 'the',
#  78: 'different',
#  79: 'uh-huh',
#  80: 'three',
#  81: 'oh',
#  82: 'really',
#  83: 'yeah',
#  84: 'yes',
#  85: 'though',
#  86: 'used',
#  87: 'when',
#  88: 'two',
#  89: 'children',
#  90: 'off',
#  91: 'on',
#  92: 'temporarily',
#  93: 'find',
#  94: 'friends',
#  95: 'babysit',
#  96: 'envy',
#  97: 'anybody',
#  98: 'who',
#  99: 'in',
#  100: 'situation',
#  101: 'day',
#  102: 'your',
#  103: 'live',
#  104: 'big',
#  105: 'community',
#  106: 'lives',
#  107: 'fairly',
#  108: 'large',
#  109: 'got',
#  110: 'real',
#  111: 'lucky',
#  112: 'boss',
#  113: 'moved',
#  114: 'into',
#  115: 'larger',
#  116: 'office',
#  117: 'able',
#  118: 'take',
#  119: 'her',
#  120: 'small',
#  121: 'works',
#  122: 'legal',
#  123: 'firm',
#  124: 'one',
#  125: 'lawyer',
#  126: 'um',
#  127: 'only',
#  128: 'takes',
#  129: 'there',
#  130: 'else',
#  131: 'they',
#  132: 'an',
#  133: 'extra',
#  134: 'room',
#  135: 'everything',
#  136: 'for',
#  137: 'out',
#  138: 'pretty',
#  139: 'good',
#  140: 'wow',
#  141: 'how',
#  142: 'lot',
#  143: 'people',
#  144: 'around',
#  145: 'here',
#  146: 'sometimes',
#  147: 'mothers',
#  148: 'grandmothers',
#  149: 'their',
#  150: "'m",
#  151: 'is',
#  152: 'are',
#  153: 'homes',
#  154: 'either',
#  155: 'them',
#  156: 'somebody',
#  157: 'knows',
#  158: 'get',
#  159: 'safe',
#  160: 'references',
#  161: 'feel',
#  162: 'comfortable',
#  163: 'leaving',
#  164: 'center',
#  165: 'simply',
#  166: 'because',
#  167: 'many',
#  168: 'worried',
#  169: "'re",
#  170: 'enough',
#  171: 'attention',
#  172: 'colds',
#  173: 'things',
#  174: 'spread',
#  175: 'easy',
#  176: 'expensive',
#  177: 'course',
#  178: 'types',
#  179: 'available',
#  180: 'too',
#  181: 'where',
#  182: 'teach',
#  183: 'academic',
#  184: 'watch',
#  185: 'let',
#  186: 'play',
#  187: 'long',
#  188: 'time',
#  189: 'right',
#  190: 'place',
#  191: 'always',
#  192: 'even',
#  193: 'be',
#  194: 'anything',
#  195: 'could',
#  196: 'happen',
#  197: 'after',
#  198: 'gets',
#  199: 'certain',
#  200: 'age',
#  201: 'starts',
#  202: 'toddling',
#  203: 'stuff',
#  204: 'ca',
#  205: 'keep',
#  206: 'control',
#  207: 'crawling',
#  208: 'would',
#  209: 'hard',
#  210: 'stressful',
#  211: 'nice',
#  212: 'seems',
#  213: 'cried',
#  214: 'at',
#  215: 'wrong',
#  216: 'phone',
#  217: 'rang',
#  218: 'problems',
#  219: 'will',
#  220: 'now',
#  221: "'ve",
#  222: 'considered',
#  223: 'neat',
#  224: 'all',
#  225: 'actually',
#  226: 'home',
#  227: 'go',
#  228: 'school',
#  229: 'called',
#  230: 'correspondence',
#  231: 'interesting',
#  232: 'special',
#  233: 'training',
#  234: 'depends',
#  235: 'state',
#  236: 'some',
#  237: 'laws',
#  238: 'absolutely',
#  239: 'prohibit',
#  240: 'states',
#  241: 'certified',
#  242: 'teacher',
#  243: 'order',
#  244: 'our',
#  245: 'yet',
#  246: 'went',
#  247: 'college',
#  248: 'elementary',
#  249: 'grades',
#  250: 'levels',
#  251: 'been',
#  252: 'public',
#  253: 'schools',
#  254: 'couple',
#  255: 'years',
#  256: 'oldest',
#  257: 'youngest',
#  258: 'never',
#  259: 'anyway',
#  260: 'company',
#  261: 'test',
#  262: 'drugs',
#  263: 'recently',
#  264: 'started',
#  265: 'policy',
#  266: 'testing',
#  267: 'which',
#  268: 'since',
#  269: 'drug',
#  270: 'own',
#  271: 'convictions',
#  272: 'clients',
#  273: 'requests',
#  274: 'huh',
#  275: 'being',
#  276: 'tested',
#  277: 'policies',
#  278: 'procedures',
#  279: 'manual',
#  280: 'furthest',
#  281: 'goes',
#  282: 'miscellaneous',
#  283: 'section',
#  284: 'reasons',
#  285: 'immediate',
#  286: 'dismissal',
#  287: 'says',
#  288: 'use',
#  289: 'narcotics',
#  290: 'premises',
#  291: 'general',
#  292: 'environmental',
#  293: 'management',
#  294: 'engineer',
#  295: 'hazardous',
#  296: 'waste',
#  297: 'sites',
#  298: 'operate',
#  299: 'machinery',
#  300: 'drill',
#  301: 'rigs',
#  302: 'under',
#  303: 'medical',
#  304: 'monitoring',
#  305: 'program',
#  306: 'higher',
#  307: 'risk',
#  308: 'exposure',
#  309: 'blood',
#  310: 'screening',
#  311: 'part',
#  312: 'capacity',
#  313: 'exclusive',
#  314: 'turns',
#  315: 'up',
#  316: 'other',
#  317: 'parameters',
#  318: 'more',
#  319: 'relevance',
#  320: 'dangerous',
#  321: 'equipment',
#  322: 'exercise',
#  323: 'quick',
#  324: 'judgment',
#  325: 'field',
#  326: 'nature',
#  327: 'business',
#  328: 'oil',
#  329: 'services',
#  330: 'companies',
#  331: 'engineers',
#  332: 'client',
#  333: 'heavy',
#  334: 'put',
#  335: 'tools',
#  336: 'very',
#  337: 'concerned',
#  338: 'adhering',
#  339: 'territory',
#  340: 'thing',
#  341: 'software',
#  342: 'house',
#  343: 'everybody',
#  344: 'getting',
#  345: 'subjected',
#  346: 'this',
#  347: 'same',
#  348: 'through',
#  349: 'than',
#  350: 'case',
#  351: 'hire',
#  352: "'ll",
#  353: 'injured',
#  354: 'job',
#  355: 'trip',
#  356: 'fall',
#  357: 'give',
#  358: 'away',
#  359: 'random',
#  360: 'were',
#  361: 'upset',
#  362: 'first',
#  363: 'particularly',
#  364: 'parties',
#  365: 'serve',
#  366: 'alcohol',
#  367: 'problem',
#  368: 'issue',
#  369: 'regular',
#  370: 'these',
#  371: 'mean',
#  372: 'brother',
#  373: 'come',
#  374: 'me',
#  375: 'twice',
#  376: 'serving',
#  377: 'beer',
#  378: 'by',
#  379: 'keg',
#  380: 'its',
#  381: 'limited',
#  382: 'should',
#  383: 'necessarily',
#  384: 'immediately',
#  385: 'accident',
#  386: 'bizarre',
#  387: 'story',
#  388: 'woman',
#  389: 'last',
#  390: 'year',
#  391: 'slip',
#  392: 'ice',
#  393: 'sprained',
#  394: 'ankle',
#  395: 'personnel',
#  396: 'secretary',
#  397: 'ambivalent',
#  398: 'whole',
#  399: 'mixed',
#  400: 'feelings',
#  401: 'hand',
#  402: 'as',
#  403: 'continue',
#  404: 'employment',
#  405: 'sense',
#  406: 'employments',
#  407: 'contractual',
#  408: 'interviewing',
#  409: 'incredibly',
#  410: 'humiliating',
#  411: 'amounted',
#  412: 'before',
#  413: 'interviews',
#  414: 'working',
#  415: 'flew',
#  416: 'chicago',
#  417: 'took',
#  418: 'doctor',
#  419: 'physical',
#  420: 'said',
#  421: 'beforehand',
#  422: 'told',
#  423: 'forgotten',
#  424: 'basically',
#  425: "'d",
#  426: 'already',
#  427: 'peed',
#  428: 'morning',
#  429: 'full',
#  430: 'sample',
#  431: 'made',
#  432: 'sit',
#  433: 'wait',
#  434: 'forty-five',
#  435: 'minutes',
#  436: 'drink',
#  437: 'ton',
#  438: 'water',
#  439: 'again',
#  440: 'procedure',
#  441: 'utterly',
#  442: 'makes',
#  443: 'clothes',
#  444: 'examines',
#  445: 'question',
#  446: 'trying',
#  447: 'together',
#  448: 'term',
#  449: 'financial',
#  450: 'plan',
#  451: 'monthly',
#  452: 'budget',
#  453: 'data',
#  454: 'quicken',
#  455: 'familiar',
#  456: 'mine',
#  457: 'using',
#  458: 'once',
#  459: 'myself',
#  460: 'decided',
#  461: 'amount',
#  462: 'information',
#  463: 'keeping',
#  464: 'date',
#  465: 'gave',
#  466: 'idea',
#  467: 'least',
#  468: 'found',
#  469: 'reliable',
#  470: 'way',
#  471: 'check',
#  472: 'book',
#  473: 'balanced',
#  474: 'wife',
#  475: 'write',
#  476: 'few',
#  477: 'checks',
#  478: 'bother',
#  479: 'total',
#  480: 'comes',
#  481: 'doing',
#  482: 'arithmetic',
#  483: 'helps',
#  484: 'similar',
#  485: 'much',
#  486: 'possible',
#  487: 'occasionally',
#  488: 'behind',
#  489: 'seem',
#  490: 'tight',
#  491: 'handle',
#  492: 'range',
#  493: 'medium',
#  494: 'planning',
#  495: 'finances',
#  496: 'until',
#  497: 'daughter',
#  498: 'eighteen',
#  499: 'another',
#  500: 'needed',
#  501: 'saving',
#  502: 'tried',
#  503: 'four',
#  504: 'thousand',
#  505: 'ten',
#  506: 'point',
#  507: 'income',
#  508: 'consider',
#  509: 'putting',
#  510: 'starting',
#  511: 'payroll',
#  512: 'deduction',
#  513: 'money',
#  514: 'making',
#  515: 'summer',
#  516: 'fund',
#  517: 'sounds',
#  518: 'family',
#  519: 'deductions',
#  520: 'probably',
#  521: 'enforce',
#  522: 'savings',
#  523: 'bit',
#  524: 'opposite',
#  525: 'cause',
#  526: 'almost',
#  527: 'sums',
#  528: 'goals',
#  529: 'sickness',
#  530: 'travel',
#  531: 'curious',
#  532: 'country',
#  533: 'stockton',
#  534: 'cincinnati',
#  535: 'wondering',
#  536: 'collecting',
#  537: 'western',
#  538: 'accents',
#  539: 'involved',
#  540: 'interested',
#  541: 'study',
#  542: 'reading',
#  543: 'telecom',
#  544: 'digest',
#  545: 'colleague',
#  546: 'over',
#  547: 'computer',
#  548: 'network',
#  549: 'internet',
#  550: 'forwarded',
#  551: 'sounded',
#  552: 'project',
#  553: 'participate',
#  554: 'sent',
#  555: 'mail',
#  556: 'base',
#  557: 'talking',
#  558: 'experiment',
#  559: 'need',
#  560: 'topic',
#  561: 'talk',
#  562: 'without',
#  563: 'dollar',
#  564: 'figures',
#  565: 'besides',
#  566: 'pursue',
#  567: 'advanced',
#  568: 'degrees',
#  569: 'factor',
#  570: 'employers',
#  571: 'every',
#  572: 'employer',
#  573: 'gives',
#  574: 'tuition',
#  575: 'reimbursement',
#  576: 'reimburse',
#  577: 'hundred',
#  578: 'percent',
#  579: 'depending',
#  580: 'grade',
#  581: 'class',
#  582: 'shame',
#  583: 'from',
#  584: 'lived',
#  585: 'europe',
#  586: 'germany',
#  587: 'jury',
#  588: 'system',
#  589: 'judges',
#  590: 'prosecuting',
#  591: 'attorney',
#  592: 'presents',
#  593: 'his',
#  594: 'evidence',
#  595: 'defense',
#  596: 'those',
#  597: 'guys',
#  598: 'figure',
#  599: 'whether',
#  600: 'guilty',
#  601: 'judicial',
#  602: 'such',
#  603: 'chaos',
#  604: 'somehow',
#  605: 'man',
#  606: 'signed',
#  607: 'statement',
#  608: 'saying',
#  609: 'murdered',
#  610: 'confessions',
#  611: 'trial',
#  612: 'twenty-two',
#  613: 'ever',
#  614: 'done',
#  615: 'bought',
#  616: 'mercedes',
#  617: 'nothing',
#  618: 'justice',
#  619: 'whatsoever',
#  620: 'look',
#  621: 'police',
#  622: 'better',
#  623: 'sure',
#  624: 'airtight',
#  625: 'sitting',
#  626: 'sorry',
#  627: 'illegally',
#  628: 'obtained',
#  629: 'whatever',
#  630: 'theatrics',
#  631: 'jumps',
#  632: 'judge',
#  633: 'disregard',
#  634: 'true',
#  635: 'welfare',
#  636: 'may',
#  637: 'utmost',
#  638: 'contempt',
#  639: 'favorite',
#  640: 'department',
#  641: 'aimed',
#  642: 'criminal',
#  643: 'citizens',
#  644: 'schedules',
#  645: 'social',
#  646: 'security',
#  647: 'numbers',
#  648: 'trace',
#  649: 'us',
#  650: 'telephones',
#  651: 'checkbooks',
#  652: 'criminals',
#  653: 'none',
#  654: 'difficult',
#  655: 'catch',
#  656: 'monetary',
#  657: 'gain',
#  658: 'whereas',
#  659: 'target',
#  660: 'efforts',
#  661: 'toward',
#  662: 'changing',
#  663: 'nailed',
#  664: 'leave',
#  665: 'details',
#  666: 'begin',
#  667: 'atlanta',
#  668: 'area',
#  669: 'crime',
#  670: 'rate',
#  671: 'astronomical',
#  672: 'streets',
#  673: 'giving',
#  674: 'speeding',
#  675: 'tickets',
#  676: 'separate',
#  677: 'revenues',
#  678: 'lawyers',
#  679: 'drop',
#  680: 'number',
#  681: 'set',
#  682: 'fees',
#  683: 'cases',
#  684: 'vein',
#  685: 'v',
#  686: 'c',
#  687: 'r',
#  688: 'television',
#  689: 'repair',
#  690: 't',
#  691: 'places',
#  692: 'dollars',
#  693: 'rooting',
#  694: 'finds',
#  695: 'tremendously',
#  696: 'eats',
#  697: 'repairs',
#  698: 'maybe',
#  699: 'blown',
#  700: 'fuse',
#  701: 'fixes',
#  702: 'still',
#  703: 'charges',
#  704: 'murder',
#  705: 'civil',
#  706: 'suing',
#  707: 'x',
#  708: 'firmly',
#  709: 'believe',
#  710: 'most',
#  711: 'heinous',
#  712: 'crimes',
#  713: 'noticed',
#  714: 'renowned',
#  715: 'bum',
#  716: 'afford',
#  717: 'paying',
#  718: 'half',
#  719: 'amazing',
#  720: 'stop',
#  721: 'former',
#  722: 'correct',
#  723: 'totally',
#  724: 'morally',
#  725: 'bankrupt',
#  726: 'ethics',
#  727: 'type',
#  728: 'person',
#  729: 'running',
#  730: 'expect',
#  731: 'anyone',
#  732: 'nursing',
#  733: 'grandparents',
#  734: 'looking',
#  735: 'grandmother',
#  736: 'alzheimer',
#  737: 'kinds',
#  738: 'trouble',
#  739: 'nuisance',
#  740: 'worse',
#  741: 'sort',
#  742: 'bananas',
#  743: 'thought',
#  744: 'deal',
#  745: 'deposit',
#  746: 'return',
#  747: 'equipped',
#  748: 'patients',
#  749: 'wanted',
#  750: 'independence',
#  751: 'meals',
#  752: 'nurse',
#  753: 'staff',
#  754: 'independent',
#  755: 'retirement',
#  756: 'hotel',
#  757: 'full-time',
#  758: 'also',
#  759: 'associated',
#  760: 'apartment',
#  761: 'eat',
#  762: 'someplace',
#  763: 'became',
#  764: 'less',
#  765: 'herself',
#  766: 'provide',
#  767: 'anymore',
#  768: 'move',
#  769: 'die',
#  770: 'quickly',
#  771: 'hope',
#  772: 'reason',
#  773: 'average',
#  774: 'length',
#  775: 'six',
#  776: 'fact',
#  777: 'help',
#  778: 'health',
#  779: 'ill',
#  780: 'yourself',
#  781: 'someone',
#  782: 'stay',
#  783: 'resort',
#  784: 'send',
#  785: 'rest',
#  786: 'relatives',
#  787: 'peace',
#  788: 'mind',
#  789: 'knowing',
#  790: 'happened',
#  791: 'thinking',
#  792: 'event',
#  793: 'emergency',
#  794: 'enjoyed',
#  795: 'while',
#  796: 'choices',
#  797: 'stuck',
#  798: 'lists',
#  799: 'want',
#  800: 'pay',
#  801: 'stage',
#  802: 'life',
#  803: 'left',
#  804: 'exactly',
#  805: 'fair',
#  806: 'younger',
#  807: 'members',
#  808: 'raise',
#  809: 'choosing',
#  810: 'based',
#  811: 'lowest',
#  812: 'price',
#  813: 'complicated',
#  814: 'outlive',
#  815: 'medicine',
#  816: 'extending',
#  817: 'quality',
#  818: 'living',
#  819: 'gone',
#  820: 'enjoying',
#  821: 'purpose',
#  822: 'worth',
#  823: 'continuing',
#  824: 'older',
#  825: 'interests',
#  826: 'spouse',
#  827: 'died',
#  828: 'alone',
#  829: 'known',
#  830: 'quite',
#  831: 'communities',
#  832: 'california',
#  833: 'elderly',
#  834: 'varies',
#  835: 'individual',
#  836: 'basis',
#  837: 'alternative',
#  838: 'benefit',
#  839: 'short',
#  840: 'especially',
#  841: 'acute',
#  842: 'illness',
#  843: 'rehab',
#  844: 'periods',
#  845: 'hump',
#  846: 'dealing',
#  847: 'often',
#  848: 'hospitals',
#  849: 'sending',
#  850: 'faster',
#  851: 'week',
#  852: 'dumb',
#  853: 'families',
#  854: 'responsibility',
#  855: 'both',
#  856: 'sides',
#  857: 'sick',
#  858: 'capable',
#  859: 'personally',
#  860: 'parents',
#  861: 'best',
#  862: 'ability',
#  863: 'impossible',
#  864: 'choice',
#  865: 'economically',
#  866: 'feasible',
#  867: 'option',
#  868: 'medicare',
#  869: 'insurance',
#  870: 'cover',
#  871: 'ahead',
#  872: 'specialties',
#  873: 'unfortunately',
#  874: 'confused',
#  875: 'mental',
#  876: 'unit',
#  877: 'locked',
#  878: 'roam',
#  879: 'trained',
#  880: 'attached',
#  881: 'liked',
#  882: 'moving',
#  883: 'volunteer',
#  884: 'eighty',
#  885: 'eventually',
#  886: 'taking',
#  887: 'burden',
#  888: 'enjoys',
#  889: 'wash',
#  890: 'dishes',
#  891: 'cook',
#  892: 'support',
#  893: 'wing',
#  894: 'likes',
#  895: 'become',
#  896: 'seen',
#  897: 'activities',
#  898: 'ones',
#  899: 'active',
#  900: 'loves',
#  901: 'great',
#  902: 'travels',
#  903: 'mountains',
#  904: 'beautiful',
#  905: 'decision',
#  906: 'needs',
#  907: 'joint',
#  908: 'between',
#  909: 'effected',
#  910: 'definitely',
#  911: 'advance',
#  912: 'fifty',
#  913: 'compared',
#  914: 'pension',
#  915: 'contribute',
#  916: 'wish',
#  917: 'o',
#  918: 'k',
#  919: 'add',
#  920: 'eight',
#  921: 'match',
#  922: 'bad',
#  923: 'contribution',
#  924: 'vest',
#  925: 'god',
#  926: 'till',
#  927: 'twenty-five',
#  928: 'thirty',
#  929: 'bucks',
#  930: 'month',
#  931: 'call',
#  932: 'flex',
#  933: 'benefits',
#  934: 'spend',
#  935: 'cafeteria',
#  936: 'otherwise',
#  937: 'lose',
#  938: 'taxed',
#  939: 'paycheck',
#  940: 'plans',
#  941: 'expenses',
#  942: 'request',
#  943: 'payment',
#  944: 'withheld',
#  945: 'saves',
#  946: 'third',
#  947: 'taxes',
#  948: 'everyone',
#  949: 'd',
#  950: 'example',
#  951: 'deductibles',
#  952: 'high',
#  953: 'fifteen',
#  954: 'unlikely',
#  955: 'relatively',
#  956: 'healthy',
#  957: 'cost',
#  958: 'analysis',
#  959: 'ends',
#  960: 'deductible',
#  961: 'loss',
#  962: 'happens',
#  963: 'car',
#  964: 'wound',
#  965: 'having',
#  966: 'bunch',
#  967: 'visits',
#  968: 'pocket',
#  969: 'screwed',
#  970: 'fault',
#  971: 'goofed',
#  972: 'blew',
#  973: 'weeks',
#  974: 'seventh',
#  975: 'service',
#  976: 'aye',
#  977: 'engineering',
#  978: 'afloat',
#  979: 'telecommunications',
#  980: 'supposedly',
#  981: 'stable',
#  982: 'bell',
#  983: 'corps',
#  984: 'model',
#  985: 'lifelong',
#  986: 'telephone',
#  987: 'pioneers',
#  988: 'america',
#  989: 'hearing',
#  990: 'laying',
#  991: 'salary',
#  992: 'trade',
#  993: 'must',
#  994: 'severance',
#  995: 'layoffs',
#  996: 'sizing',
#  997: 'rid',
#  998: 'layers',
#  999: 'manage',
#  ...}

# %%
tags = pd.concat([train_data['tag'], valid_data['tag'], test_data['tag']], axis=0, ignore_index=True)
tags
# Out:
# 0         fo_o_fw_"_by_bc
# 1                      qw
# 2                    qy^d
# 3                      qy
# 4                      sd
#                ...
# 199731                 fc
# 199732                 fc
# 199733                 fc
# 199734                 fc
# 199735                 fc
# Name: tag, Length: 199736, dtype: object

# %%
labels = list(tags.unique())
# idx2label = {i:l for i,l in enumerate(labels)}
# label2idx = {l:i for i,l in idx2label.items()}
label2idx = {l:i for i,l in enumerate(labels)}

# %%
label2idx
# Out:
# {'fo_o_fw_"_by_bc': 0,
#  'qw': 1,
#  'qy^d': 2,
#  'qy': 3,
#  'sd': 4,
#  'ad': 5,
#  'h': 6,
#  'aa': 7,
#  'b': 8,
#  'sv': 9,
#  'bk': 10,
#  'nn': 11,
#  'na': 12,
#  'bh': 13,
#  'ny': 14,
#  '%': 15,
#  'ba': 16,
#  'bf': 17,
#  'b^m': 18,
#  'qh': 19,
#  'no': 20,
#  't1': 21,
#  'qo': 22,
#  '^h': 23,
#  'qrr': 24,
#  'oo_co_cc': 25,
#  '^q': 26,
#  '^2': 27,
#  'br': 28,
#  'aap_am': 29,
#  'bd': 30,
#  '^g': 31,
#  'fc': 32,
#  'ft': 33,
#  'ar': 34,
#  't3': 35,
#  'ng': 36,
#  'qw^d': 37,
#  'fp': 38,
#  'fa': 39,
#  'arp_nd': 40}

# %%
config = {
    "n_words" : len(word2idx)-1,
    "n_tags": len(label2idx),
    "n_train": len(train_data),
    "n_valid": len(valid_data),
    "n_test": len(test_data)
}

# %%
with open(data_dir / "word2idx.json", "w") as f:
    json.dump(word2idx, f)

# with open(data_dir / "idx2word.json", "w") as f:
#     json.dump(idx2word, f)
    
with open(data_dir / "label2idx.json", "w") as f:
    json.dump(label2idx, f)
    
# with open(data_dir / "idx2label.json", "w") as f:
#     json.dump(idx2word, f)
    
with open(data_dir / "config.json", "w") as f:
    json.dump(config, f)

# %%
import numpy as np
embedding_dim = 100
pretrained_embeddings = f"glove.6b.{embedding_dim}d.txt"
embeddings = {}
with open(data_dir / pretrained_embeddings, encoding="utf8") as file:
        for line in file:
            values = line.rstrip().rsplit(' ')
            word = values[0]
            vector = np.asarray(values[1:], dtype='float32')
            embeddings[word] = vector

# %%
embedding_matrix = np.zeros((len(word2idx), embedding_dim))

# %%
for word, idx in word2idx.items():
    if word in embeddings.keys():
        word_embedding = embeddings[word]
        embedding_matrix[idx] = word_embedding

# %%
with open(data_dir / "embeddings.pkl", "wb") as f:
    pickle.dump(embedding_matrix, f)
